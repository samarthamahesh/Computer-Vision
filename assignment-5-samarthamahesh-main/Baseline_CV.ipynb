# %% [markdown]
# # Getting Started Code for [Chunin Exams Food Track- CV'2021](https://www.aicrowd.com/challenges/chunin-exams-food-track-cv-2021) on AIcrowd
# #### Author : Pulkit Gera

# %% [markdown]
# ## Download Necessary Packages 📚

# %%
# !pip3 install aicrowd-cli
# Out:
# Requirement already satisfied: aicrowd-cli in /home/samarthamahesh/.local/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied: requests-toolbelt<1,>=0.9.1 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (0.9.1)
# Requirement already satisfied: rich<11,>=10.0.0 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (10.1.0)
# Requirement already satisfied: click<8,>=7.1.2 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (7.1.2)
# Requirement already satisfied: requests<3,>=2.25.1 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (2.25.1)
# Requirement already satisfied: gitpython<4,>=3.1.12 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (3.1.14)
# Requirement already satisfied: tqdm<5,>=4.56.0 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (4.56.0)
# Requirement already satisfied: toml<1,>=0.10.2 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from aicrowd-cli) (0.10.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (2.7.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (0.4.4)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (2019.11.28)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from gitpython<4,>=3.1.12->aicrowd-cli) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/samarthamahesh/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.12->aicrowd-cli) (4.0.0)

# %% [markdown]
# ## Download Data
# The first step is to download out train test data. We will be training a model on the train data and make predictions on test data. We submit our predictions.

# %%
API_KEY = "a48e9c507be2be15318feaa6f3182190" #Please enter your API Key from [https://www.aicrowd.com/participants/me]
# !aicrowd login --api-key $API_KEY
# Out:
# API Key valid
# Saved API Key successfully!

# %%
# !aicrowd dataset download --challenge chunin-exams-food-track-cv-2021
# Out:
# test.csv: 100%|████████████████████████████| 7.27k/7.27k [00:00<00:00, 2.72MB/s]
# test_images.zip:   0%|                              | 0.00/33.9M [00:00<?, ?B/s]
# train.csv:   0%|                                     | 0.00/253k [00:00<?, ?B/s]
#
# test_images.zip:   3%|▋                     | 1.05M/33.9M [00:01<00:54, 598kB/s]
# train.csv: 100%|█████████████████████████████| 253k/253k [00:15<00:00, 16.2kB/s]
# test_images.zip:  15%|███▍                  | 5.24M/33.9M [00:20<01:21, 351kB/s]
#
# test_images.zip:  25%|█████▍                | 8.39M/33.9M [00:25<00:58, 439kB/s]
#
# test_images.zip:  28%|██████                | 9.44M/33.9M [00:25<00:45, 541kB/s]
#
# test_images.zip:  31%|██████▊               | 10.5M/33.9M [00:28<00:49, 477kB/s]
#
# test_images.zip:  34%|███████▍              | 11.5M/33.9M [00:29<00:36, 608kB/s]
#
# train_images.zip:   1%|▏                     | 5.24M/754M [00:28<37:49, 330kB/s]
#
# test_images.zip:  37%|████████▏             | 12.6M/33.9M [00:32<00:43, 489kB/s]
#
# test_images.zip:  40%|████████▊             | 13.6M/33.9M [00:34<00:38, 528kB/s]
#
# train_images.zip:   1%|▏                     | 8.39M/754M [00:32<22:53, 543kB/s]
#
# train_images.zip:   1%|▎                     | 10.5M/754M [00:35<17:40, 701kB/s]
#
# test_images.zip:  43%|█████████▌            | 14.7M/33.9M [00:36<00:38, 505kB/s]
#
# test_images.zip:  49%|██████████▉           | 16.8M/33.9M [00:38<00:25, 665kB/s]
#
# test_images.zip:  53%|███████████▌          | 17.8M/33.9M [00:40<00:24, 660kB/s]
#
# train_images.zip:   2%|▍                    | 15.7M/754M [00:39<11:39, 1.06MB/s]
#
# test_images.zip:  56%|████████████▏         | 18.9M/33.9M [00:41<00:20, 719kB/s]
#
# train_images.zip:   2%|▍                    | 17.8M/754M [00:40<09:43, 1.26MB/s]
#
# test_images.zip:  59%|████████████▉         | 19.9M/33.9M [00:43<00:20, 677kB/s]
#
# train_images.zip:   3%|▌                    | 19.9M/754M [00:42<09:15, 1.32MB/s]
#
# train_images.zip:   3%|▌                    | 21.0M/754M [00:42<08:09, 1.50MB/s]
#
# test_images.zip:  62%|█████████████▌        | 21.0M/33.9M [00:45<00:19, 661kB/s]
#
# test_images.zip:  65%|██████████████▎       | 22.0M/33.9M [00:46<00:17, 691kB/s]
#
# train_images.zip:   3%|▋                    | 24.1M/754M [00:45<09:09, 1.33MB/s]
#
# test_images.zip:  68%|██████████████▉       | 23.1M/33.9M [00:48<00:16, 644kB/s]
#
# test_images.zip:  71%|███████████████▋      | 24.1M/33.9M [00:50<00:16, 581kB/s]
#
# train_images.zip:   4%|▊                     | 27.3M/754M [00:49<13:28, 900kB/s]
#
# test_images.zip:  74%|████████████████▎     | 25.2M/33.9M [00:50<00:11, 760kB/s]
#
# train_images.zip:   4%|▊                    | 29.4M/754M [00:50<09:06, 1.33MB/s]
#
# test_images.zip:  77%|█████████████████     | 26.2M/33.9M [00:52<00:09, 803kB/s]
#
# train_images.zip:   4%|▉                    | 31.5M/754M [00:51<08:22, 1.44MB/s]
#
# test_images.zip:  80%|█████████████████▋    | 27.3M/33.9M [00:54<00:10, 643kB/s]
#
# test_images.zip:  84%|██████████████████▎   | 28.3M/33.9M [00:54<00:06, 832kB/s]
#
# train_images.zip:   5%|█                     | 34.6M/754M [00:55<12:33, 955kB/s]
#
# test_images.zip:  87%|███████████████████   | 29.4M/33.9M [00:57<00:06, 671kB/s]
#
# test_images.zip:  90%|███████████████████▋  | 30.4M/33.9M [00:59<00:06, 550kB/s]
#
# test_images.zip:  93%|████████████████████▍ | 31.5M/33.9M [01:00<00:03, 705kB/s]
#
# train_images.zip:   5%|█▏                    | 38.8M/754M [01:00<14:59, 796kB/s]
#
# test_images.zip:  96%|█████████████████████ | 32.5M/33.9M [01:02<00:02, 598kB/s]
#
# test_images.zip: 100%|██████████████████████| 33.9M/33.9M [01:04<00:00, 528kB/s]
#
#
# train_images.zip:   6%|█▏                   | 41.9M/754M [01:03<10:27, 1.13MB/s]
#
# train_images.zip:   6%|█▏                   | 43.0M/754M [01:03<09:08, 1.30MB/s]
#
# train_images.zip:   6%|█▏                   | 44.0M/754M [01:04<09:25, 1.26MB/s]
#
# train_images.zip:   6%|█▎                   | 45.1M/754M [01:05<08:26, 1.40MB/s]
#
# train_images.zip:   6%|█▎                    | 46.1M/754M [01:09<21:59, 537kB/s]
#
# train_images.zip:   6%|█▍                    | 48.2M/754M [01:10<13:39, 862kB/s]
#
# train_images.zip:   7%|█▎                   | 49.3M/754M [01:11<11:36, 1.01MB/s]
#
# train_images.zip:   7%|█▍                   | 50.3M/754M [01:11<09:39, 1.22MB/s]
#
# train_images.zip:   7%|█▍                    | 51.4M/754M [01:13<13:31, 866kB/s]
#
# train_images.zip:   7%|█▍                   | 52.4M/754M [01:14<11:27, 1.02MB/s]
#
# train_images.zip:   7%|█▍                   | 53.5M/754M [01:14<10:07, 1.15MB/s]
#
# train_images.zip:   7%|█▌                   | 54.5M/754M [01:15<09:04, 1.29MB/s]
#
# train_images.zip:   7%|█▌                   | 55.6M/754M [01:16<11:39, 1.00MB/s]
#
# train_images.zip:   8%|█▋                    | 57.7M/754M [01:21<16:40, 697kB/s]
#
# train_images.zip:   8%|█▋                    | 58.7M/754M [01:22<17:18, 670kB/s]
#
# train_images.zip:   8%|█▊                    | 60.8M/754M [01:23<11:39, 991kB/s]
#
# train_images.zip:   8%|█▋                   | 61.9M/754M [01:23<10:09, 1.14MB/s]
#
# train_images.zip:   8%|█▊                    | 62.9M/754M [01:25<11:56, 965kB/s]
#
# train_images.zip:   8%|█▊                   | 64.0M/754M [01:26<10:04, 1.14MB/s]
#
# train_images.zip:   9%|█▊                   | 65.0M/754M [01:26<08:28, 1.36MB/s]
#
# train_images.zip:   9%|█▊                   | 66.1M/754M [01:27<09:34, 1.20MB/s]
#
# train_images.zip:   9%|█▉                   | 68.2M/754M [01:28<07:36, 1.50MB/s]
#
# train_images.zip:   9%|█▉                   | 69.2M/754M [01:28<07:06, 1.61MB/s]
#
# train_images.zip:   9%|█▉                   | 70.3M/754M [01:30<08:12, 1.39MB/s]
#
# train_images.zip:  10%|██                   | 72.4M/754M [01:31<07:07, 1.60MB/s]
#
# train_images.zip:  10%|██                   | 73.4M/754M [01:31<06:45, 1.68MB/s]
#
# train_images.zip:  10%|██                   | 74.4M/754M [01:32<06:33, 1.73MB/s]
#
# train_images.zip:  10%|██                   | 75.5M/754M [01:32<07:00, 1.61MB/s]
#
# train_images.zip:  10%|██▏                  | 76.5M/754M [01:33<06:35, 1.71MB/s]
#
# train_images.zip:  10%|██▏                  | 77.6M/754M [01:33<05:35, 2.02MB/s]
#
# train_images.zip:  10%|██▏                  | 78.6M/754M [01:34<06:18, 1.78MB/s]
#
# train_images.zip:  11%|██▎                   | 79.7M/754M [01:37<12:58, 867kB/s]
#
# train_images.zip:  11%|██▍                   | 81.8M/754M [01:43<21:56, 511kB/s]
#
# train_images.zip:  11%|██▍                   | 82.8M/754M [01:47<27:20, 409kB/s]
#
# train_images.zip:  11%|██▍                   | 84.9M/754M [01:48<18:23, 607kB/s]
#
# train_images.zip:  11%|██▌                   | 86.0M/754M [01:49<15:16, 730kB/s]
#
# train_images.zip:  12%|██▌                   | 87.0M/754M [01:50<16:32, 673kB/s]
#
# train_images.zip:  12%|██▌                   | 88.1M/754M [01:51<13:43, 809kB/s]
#
# train_images.zip:  12%|██▌                   | 89.1M/754M [01:51<11:14, 986kB/s]
#
# train_images.zip:  12%|██▋                   | 90.2M/754M [01:57<25:36, 432kB/s]
#
# train_images.zip:  12%|██▋                   | 91.2M/754M [02:08<25:34, 432kB/s]
#
# train_images.zip:  12%|██▋                   | 92.3M/754M [02:09<41:53, 263kB/s]
#
# train_images.zip:  12%|██▋                   | 93.3M/754M [02:15<45:46, 241kB/s]
#
# train_images.zip:  13%|██▊                   | 94.4M/754M [02:15<35:30, 310kB/s]
#
# train_images.zip:  13%|██▊                   | 95.4M/754M [02:17<30:24, 361kB/s]
#
# train_images.zip:  13%|██▊                   | 96.5M/754M [02:20<30:22, 361kB/s]
#
# train_images.zip:  13%|██▊                   | 97.5M/754M [02:30<52:09, 210kB/s]
#
# train_images.zip:  13%|██▊                   | 98.6M/754M [02:31<40:42, 269kB/s]
#
# train_images.zip:  13%|██▉                   | 99.6M/754M [02:32<31:17, 349kB/s]
#
# train_images.zip:  13%|███                    | 101M/754M [02:36<33:45, 323kB/s]
# train_images.zip:  13%|███                    | 102M/754M [02:37<25:25, 428kB/s]
#
# train_images.zip:  14%|███▏                   | 103M/754M [02:38<20:59, 517kB/s]
#
# train_images.zip:  14%|███▏                   | 104M/754M [02:38<16:57, 639kB/s]
#
# train_images.zip:  14%|███▏                   | 105M/754M [02:39<13:50, 782kB/s]
#
# train_images.zip:  14%|███▏                   | 106M/754M [02:40<11:49, 914kB/s]
#
# train_images.zip:  14%|███                   | 107M/754M [02:40<10:32, 1.02MB/s]
#
# train_images.zip:  14%|███▎                   | 108M/754M [02:42<11:29, 937kB/s]
#
# train_images.zip:  14%|███▎                   | 109M/754M [02:45<18:38, 577kB/s]
#
# train_images.zip:  15%|███▎                   | 110M/754M [02:46<14:16, 753kB/s]
#
# train_images.zip:  15%|███▍                   | 111M/754M [02:46<12:23, 866kB/s]
#
# train_images.zip:  15%|███▎                  | 112M/754M [02:47<10:24, 1.03MB/s]
#
# train_images.zip:  15%|███▎                  | 113M/754M [02:48<09:33, 1.12MB/s]
#
# train_images.zip:  15%|███▍                   | 114M/754M [02:50<13:15, 805kB/s]
#
# train_images.zip:  15%|███▌                   | 115M/754M [02:55<24:10, 441kB/s]
#
# train_images.zip:  15%|███▌                   | 116M/754M [02:55<18:02, 589kB/s]
#
# train_images.zip:  16%|███▌                   | 117M/754M [02:55<13:36, 781kB/s]
#
# train_images.zip:  16%|███▌                   | 118M/754M [02:56<11:25, 928kB/s]
#
# train_images.zip:  16%|███▍                  | 120M/754M [02:57<09:44, 1.09MB/s]
#
# train_images.zip:  16%|███▌                  | 121M/754M [02:57<08:35, 1.23MB/s]
#
# train_images.zip:  16%|███▌                  | 122M/754M [02:58<07:39, 1.38MB/s]
#
# train_images.zip:  16%|███▌                  | 123M/754M [02:58<06:58, 1.51MB/s]
#
# train_images.zip:  16%|███▌                  | 124M/754M [02:59<06:24, 1.64MB/s]
#
# train_images.zip:  17%|███▋                  | 125M/754M [02:59<05:48, 1.81MB/s]
#
# train_images.zip:  17%|███▋                  | 126M/754M [03:00<05:28, 1.92MB/s]
#
# train_images.zip:  17%|███▊                   | 127M/754M [03:05<19:31, 536kB/s]
#
# train_images.zip:  17%|███▉                   | 128M/754M [03:05<15:01, 695kB/s]
#
# train_images.zip:  17%|███▉                   | 129M/754M [03:08<17:38, 591kB/s]
#
# train_images.zip:  17%|███▉                   | 131M/754M [03:11<16:49, 617kB/s]
#
# train_images.zip:  18%|████                   | 132M/754M [03:11<13:36, 762kB/s]
#
# train_images.zip:  18%|████                   | 133M/754M [03:15<19:07, 541kB/s]
#
# train_images.zip:  18%|████                   | 134M/754M [03:18<22:32, 458kB/s]
#
# train_images.zip:  18%|████▏                  | 136M/754M [03:19<13:48, 746kB/s]
#
# train_images.zip:  18%|████▏                  | 137M/754M [03:19<11:35, 887kB/s]
#
# train_images.zip:  18%|████                  | 138M/754M [03:20<09:41, 1.06MB/s]
#
# train_images.zip:  18%|████                  | 139M/754M [03:20<08:07, 1.26MB/s]
#
# train_images.zip:  19%|████                  | 141M/754M [03:20<07:06, 1.44MB/s]
#
# train_images.zip:  19%|████▏                 | 142M/754M [03:21<06:14, 1.63MB/s]
#
# train_images.zip:  19%|████▏                 | 143M/754M [03:23<09:28, 1.08MB/s]
#
# train_images.zip:  19%|████▏                 | 144M/754M [03:23<08:01, 1.27MB/s]
#
# train_images.zip:  19%|████▏                 | 145M/754M [03:24<06:48, 1.49MB/s]
#
# train_images.zip:  19%|████▎                 | 146M/754M [03:24<06:11, 1.64MB/s]
#
# train_images.zip:  19%|████▎                 | 147M/754M [03:25<05:56, 1.70MB/s]
#
# train_images.zip:  20%|████▎                 | 148M/754M [03:25<05:43, 1.77MB/s]
#
# train_images.zip:  20%|████▎                 | 149M/754M [03:26<05:12, 1.94MB/s]
#
# train_images.zip:  20%|████▎                 | 150M/754M [03:27<07:19, 1.38MB/s]
#
# train_images.zip:  20%|████▍                 | 151M/754M [03:28<09:34, 1.05MB/s]
#
# train_images.zip:  20%|████▍                 | 152M/754M [03:29<07:42, 1.30MB/s]
#
# train_images.zip:  20%|████▍                 | 153M/754M [03:29<06:39, 1.51MB/s]
#
# train_images.zip:  20%|████▍                 | 154M/754M [03:30<06:07, 1.64MB/s]
#
# train_images.zip:  21%|████▌                 | 155M/754M [03:30<05:32, 1.80MB/s]
#
# train_images.zip:  21%|████▌                 | 156M/754M [03:31<07:33, 1.32MB/s]
#
# train_images.zip:  21%|████▌                 | 158M/754M [03:33<08:05, 1.23MB/s]
#
# train_images.zip:  21%|████▋                 | 159M/754M [03:34<07:47, 1.27MB/s]
#
# train_images.zip:  21%|████▉                  | 160M/754M [03:36<09:56, 995kB/s]
#
# train_images.zip:  21%|████▋                 | 161M/754M [03:36<08:03, 1.23MB/s]
#
# train_images.zip:  22%|████▋                 | 163M/754M [03:36<06:50, 1.44MB/s]
#
# train_images.zip:  22%|████▊                 | 164M/754M [03:37<06:06, 1.61MB/s]
#
# train_images.zip:  22%|████▊                 | 165M/754M [03:37<05:28, 1.79MB/s]
#
# train_images.zip:  22%|████▊                 | 166M/754M [03:38<05:03, 1.94MB/s]
#
# train_images.zip:  22%|████▊                 | 167M/754M [03:39<07:06, 1.38MB/s]
#
# train_images.zip:  22%|████▉                 | 169M/754M [03:40<05:11, 1.88MB/s]
#
# train_images.zip:  23%|████▉                 | 170M/754M [03:41<07:58, 1.22MB/s]
#
# train_images.zip:  23%|█████                 | 172M/754M [03:44<09:32, 1.02MB/s]
#
# train_images.zip:  23%|█████                 | 173M/754M [03:45<08:54, 1.09MB/s]
#
# train_images.zip:  23%|█████▎                 | 174M/754M [03:55<30:21, 319kB/s]
#
# train_images.zip:  23%|█████▎                 | 175M/754M [03:56<23:35, 409kB/s]
#
# train_images.zip:  23%|█████▎                 | 176M/754M [03:56<18:17, 527kB/s]
#
# train_images.zip:  23%|█████▍                 | 177M/754M [04:07<40:01, 240kB/s]
#
# train_images.zip:  24%|█████▍                 | 178M/754M [04:07<30:48, 312kB/s]
#
# train_images.zip:  24%|█████▍                 | 179M/754M [04:10<29:23, 326kB/s]
#
# train_images.zip:  24%|█████▍                 | 180M/754M [04:11<22:02, 434kB/s]
#
# train_images.zip:  24%|█████▌                 | 181M/754M [04:13<20:09, 474kB/s]
#
# train_images.zip:  24%|█████▌                 | 182M/754M [04:14<17:17, 551kB/s]
#
# train_images.zip:  24%|█████▌                 | 184M/754M [04:15<16:55, 562kB/s]
#
# train_images.zip:  24%|█████▋                 | 185M/754M [04:16<13:01, 729kB/s]
#
# train_images.zip:  25%|█████▋                 | 186M/754M [04:21<22:02, 430kB/s]
#
# train_images.zip:  25%|█████▋                 | 187M/754M [04:23<22:16, 425kB/s]
#
# train_images.zip:  25%|█████▊                 | 189M/754M [04:24<13:35, 693kB/s]
#
# train_images.zip:  25%|█████▊                 | 190M/754M [04:25<12:49, 734kB/s]
#
# train_images.zip:  25%|█████▊                 | 191M/754M [04:26<11:08, 843kB/s]
#
# train_images.zip:  25%|█████▊                 | 192M/754M [04:27<09:48, 956kB/s]
#
# train_images.zip:  26%|█████▋                | 193M/754M [04:27<08:40, 1.08MB/s]

# %%
# !rm -rf data
# !mkdir data

# %% [markdown]
# ## Making Direct Submission thought Aicrowd CLI

# %%
# !aicrowd submission create -c chunin-exams-food-track-cv-2021 -f submission.csv
# Out:
# submission.csv ━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 13.1/11.5 KB • 1.4 MB/s • 0:00:00
#                                                  ╭─────────────────────────╮
#                                                  │ Successfully submitted! │
#                                                  ╰─────────────────────────╯
#                                                        Important links
# ┌──────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │  This submission │ https://www.aicrowd.com/challenges/ai-blitz-7/problems/stage-prediction/submissions/125933              │
# │                  │                                                                                                         │
# │  All submissions │ https://www.aicrowd.com/challenges/ai-blitz-7/problems/stage-prediction/submissions?my_submissions=true │
# │                  │                                                                                                         │
# │      Leaderboard │ https://www.aicrowd.com/challenges/ai-blitz-7/problems/stage-prediction/leaderboards                    │
# │                  │                                                                                                         │
# │ Discussion forum │ https://discourse.aicrowd.com/c/ai-blitz-7                                                              │
# │                  │                                                                                                         │
# │   Challenge page │ https://www.aicrowd.com/challenges/ai-blitz-7/problems/stage-prediction                                 │
# └──────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# {'submission_id': 125933, 'created_at': '2021-03-12T14:32:25.301Z'}
