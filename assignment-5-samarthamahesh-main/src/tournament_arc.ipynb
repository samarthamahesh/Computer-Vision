# %%
import cv2
import os
from tqdm.notebook import tqdm
import numpy as np
np.random.seed(43)
 
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
 
from skimage.transform import rotate, AffineTransform, warp
from skimage.util import random_noise
from skimage.filters import gaussian
 
import torch
torch.manual_seed(43)
import torch.nn as nn
import torch.nn.functional as F
 
from torchvision import models
from torchvision.datasets import ImageFolder
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split, RandomSampler
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/IIIT HYDERABAD/SEMESTER 6/CV/Assignment 5/train.zip" -d "/content/temp_train/"
# !unzip "/content/drive/My Drive/IIIT HYDERABAD/SEMESTER 6/CV/Assignment 5/test.zip" -d "/content/temp_test/"

# !mv "/content/temp_train/content/drive/MyDrive/CV_a5/train_images/" "/content/"
# !mv "/content/temp_test/content/drive/MyDrive/CV_a5/test_images/" "/content/"

# !cp "/content/drive/My Drive/IIIT HYDERABAD/SEMESTER 6/CV/Assignment 5/train.csv" "/content/"
# !cp "/content/drive/My Drive/IIIT HYDERABAD/SEMESTER 6/CV/Assignment 5/test.csv" "/content/"
# !cp "/content/drive/My Drive/IIIT HYDERABAD/SEMESTER 6/CV/Assignment 5/dataset_info.txt" "/content/"
# !rm -r "/content/temp_train"
# !rm -r "/content/temp_test"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/8d00a03172.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/15a87d4817.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/f44c29ece5.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/45dba3fe97.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c756b82015.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/0e2bdc7ba8.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b5cbc0056c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/10982b2133.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/617b7641b3.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6601b6bd82.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/579bf0df0c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b6768f2f16.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/55e1b0806c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b9525a8756.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c03906b13f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/ea1de7cdbc.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/11b4dd514c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3263d8017f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/f8e5d0b883.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3a45be44ee.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d128feba23.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/a3c79fb490.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/93238c9b55.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c100606eb7.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d2507f1039.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/4059c2ca1f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/1eaba5d31a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b16cf82d4f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/2613033fb3.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/23929cf555.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/53da8634be.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b452bf4d05.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/42e6135199.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/e3e76a3d9c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/920b434675.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/67875213b4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/a52b2de219.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/08c4d6deed.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b24788a803.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/a4bebe6090.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3196edb2ef.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6f61d4e92a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/ba3462df5f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3d49102d9b.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/4f64237589.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/7c002c058a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/46f0024c56.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/fd85f67571.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/4f12d4733d.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/20cbfb9d7a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c4d126fbdd.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/1f7a65048b.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/751e41a472.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/8637f12c35.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/1f6506a07f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/12294127ed.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/827530fd5e.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/aee2639c4d.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/67d27b57d5.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/901a583ff2.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/252588e39b.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/4094a9110a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d0be1ea4fc.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d4d6b61750.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/98905bcb9f.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/0fd39154d1.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/02c48efcf0.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/174abe7af5.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d593c05def.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/f3a74d6ee0.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/767402f85c.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/55568bc85e.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6aefc0af23.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/31472cb64a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/a7537470dd.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c3a4bbffde.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/54ac2c81d8.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/26a0e9e47e.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6c7c16c2be.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/fb26e585b1.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/8b0ea00050.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/0a2842082d.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3219aa4d86.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6c603ead01.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/b16a4010fc.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/44619cd413.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/46cf7f0910.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/39deca95a1.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d8c6dd4a4e.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/aae23557fd.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/8f2f1a556b.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/0987d45ef4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6a6f2b93f4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/9aa14a0d5d.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/aa20935f46.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/74f48f0088.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/0a8c7667b3.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/bb62c67ddb.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/31bc375941.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/e37a83cf04.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/aa59004acd.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/22b0b427c4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/ac8f7219b3.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6a3734eb47.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/045e9022a9.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/e911b28bd4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/e19dacc975.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/9d58b54d54.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/6ca6700747.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/c29f9852fb.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/1be673bb2a.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/4c20c793a9.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/3e263eedd4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/1068fe3ab4.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/da28faf999.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/55fc949f91.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/76dd79e5fd.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/13b66f0e54.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/87ced8bc48.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/a01113b122.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/fb5fbd2f01.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/85886ab839.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/ec934fd9cf.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/d62a77f758.jpg
#   inflating: /content/temp_train/content/drive/MyDrive/CV_a5/train_images/
jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/584490f483.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/0c3bf8b3bb.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/1f1d2ad878.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/a05a4fe910.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/7a03178a5d.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/afd4cdd8fe.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/d83480b30b.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/e68641475c.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/2b78d749e7.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/d5df1ab5ec.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/75e18d22de.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/90e538b002.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/69a5cb00e5.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/f2d03571aa.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/71e61d2081.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/8986e1389e.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/9e83f396c1.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/be2eb5f164.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/f88c263c1d.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/9ec824d4be.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/a87c002eb4.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/a4fee8009d.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/d90761a694.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/c8159e2dcd.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/a64d292c5b.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/5d198e6074.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/75f1fea87f.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/4cd5ac3700.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/a6b9bdc6b3.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/7fea41cb9c.jpg
#   inflating: /content/temp_test/content/drive/MyDrive/CV_a5/test_images/c8cd5c0582.jpg

# %%
assign_path = "/content/"

train_path = assign_path + "train_images/"
train_csv = assign_path + "train.csv"
test_path = assign_path + "test_images/"
test_csv = assign_path + "test.csv"
class_info = assign_path + "dataset_info.txt"

# %%
with open(class_info, 'r') as f:
    data = f.read()
    data = data.split('\n')[1:]
    classes = []
    for i in data:
        classes.append(i.split('.')[1].strip())

class2index = {c: i for i, c in enumerate(classes)}
index2class = {class2index[c]: c for c in class2index}

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, folder, class2index, transform=None):
        self.df = pd.read_csv(csv_path)
        self.folder = folder
        self.transform = transform
        self.class2index = class2index
        self.num = len(self.df)
 
    def __len__(self):
        return 5*len(self.df)
 
    def __getitem__(self, index):
        fname = self.df['ImageId'][index%self.num]
        label = self.class2index[self.df["ClassName"][index%self.num]]
        image = Image.open(os.path.join(self.folder, fname))
        if index // self.num == 1:
            image = image.transpose(Image.ROTATE_90)
        elif index // self.num == 2:
            image = image.transpose(Image.ROTATE_90).transpose(Image.ROTATE_90)
        elif index // self.num == 3:
            image = image.transpose(Image.FLIP_TOP_BOTTOM)
        elif index // self.num == 4:
            image = image.transpose(Image.FLIP_LEFT_RIGHT)
 
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((128, 128))
])

dataset = Dataset(train_csv, train_path, class2index, transform)

# %%
val_size = int(0.1*len(dataset))
train_size = len(dataset) - val_size

train_ds, val_ds = random_split(dataset, [train_size, val_size])

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device)

class DeviceLoader():
    def __init__(self, loader, device):
        self.loader = loader
        self.device = device

    def __iter__(self):
        for batch in self.loader:
            yield to_device(batch, self.device)

# %%
def train(model, train_loader, val_loader, epochs, lr, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    history = {
        'train_loss': [],
        'val_loss': [],
        'val_acc': []
    }

    min_val_loss = np.inf
    max_val_acc = 0
    for epoch in tqdm(range(epochs)):
        model.train()
        train_losses = []
        for i, batch in enumerate(tqdm(train_loader)):
            optimizer.zero_grad()
            imgs, labs = batch
            out = model.forward(imgs)
            loss = nn.CrossEntropyLoss()(out, labs)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_losses = []
            val_accs = []
            for batch in tqdm(val_loader):
                imgs, labs = batch
                out = model.forward(imgs)
                loss = nn.CrossEntropyLoss()(out, labs)
                val_losses.append(loss)
                acc = accuracy(out, labs)
                val_accs.append(acc)
        
        history['train_loss'].append(torch.stack(train_losses).mean().item())
        history['val_loss'].append(torch.stack(val_losses).mean().item())
        history['val_acc'].append(torch.stack(val_accs).mean().item())

        if history['val_loss'][epoch] < min_val_loss:
            min_val_loss = history['val_loss'][epoch]
            torch.save(model, './best_loss_model')

        if history['val_acc'][epoch] > max_val_acc:
            max_val_acc = history['val_acc'][epoch]
            torch.save(model, './best_acc_model')
        
        print('Epoch: ' + str(epoch+1) + ', Train loss: ' + str(history['train_loss'][epoch])
                            + ', Validation loss: ' + str(history['val_loss'][epoch])
                            + ', Validation accuracy: ' + str(history['val_acc'][epoch]))
        
    return history

def accuracy(outputs, labels):
    softmax = nn.Softmax(dim=1)
    _, preds = torch.max(softmax(outputs), dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
def plot_graphs(history):
    fig = plt.figure(figsize=(24, 8))

    # Train Loss and Validation loss
    axs = fig.add_subplot(121)
    no_ep = len(history['val_loss'])
    axs.plot(np.arange(no_ep)+1, history['train_loss'], label='Train Loss')
    axs.plot(np.arange(no_ep)+1, history['val_loss'], label='Val Loss')
    axs.set_title('Losses vs Epoch', fontsize=20)
    axs.xaxis.label.set_size(40)
    axs.set_xlabel('Epoch', fontsize=15)
    axs.set_ylabel('Loss', fontsize=15)
    axs.legend(fontsize=15)

    # Validation accuracy
    axs = fig.add_subplot(122)
    no_ep = len(history['val_acc'])
    axs.plot(np.arange(no_ep)+1, history['val_acc'])
    axs.set_title('Validation accuracy vs Epoch', fontsize=20)
    axs.set_xlabel('Epoch', fontsize=15)
    axs.set_ylabel('Validation accuracy', fontsize=15)

# %%
batch_size = 64

train_dl = DataLoader(train_ds, batch_size, shuffle=True)
val_dl = DataLoader(val_ds, batch_size, shuffle=True)

# %%
train_dl = DeviceLoader(train_dl, device)
val_dl = DeviceLoader(val_dl, device)

# %%
model = models.resnet50(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

num_features = model.fc.in_features

model.fc = nn.Sequential(
    nn.Linear(in_features, 1024),
    nn.ReLU(),
    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 62)
)

# %%
model
to_device(model, device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=62, bias=True)
#   )
# )

# %%
num_epochs = 7
opt_func = torch.optim.Adam
lr = 0.001

# %%
history = train(model, train_dl, val_dl, num_epochs, lr, opt_func)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 1, Train loss: 2.4353864192962646, Validation loss: 2.0409910678863525, Validation accuracy: 0.4359895884990692
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 2, Train loss: 1.8594796657562256, Validation loss: 1.7375296354293823, Validation accuracy: 0.5047937035560608
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 3, Train loss: 1.642054796218872, Validation loss: 1.6205295324325562, Validation accuracy: 0.523798942565918
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 4, Train loss: 1.4801222085952759, Validation loss: 1.5195468664169312, Validation accuracy: 0.5381397008895874
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 5, Train loss: 1.33906888961792, Validation loss: 1.3948194980621338, Validation accuracy: 0.5731172561645508
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 6, Train loss: 1.199718713760376, Validation loss: 1.3637412786483765, Validation accuracy: 0.5876801609992981
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch: 7, Train loss: 1.073615312576294, Validation loss: 1.2636046409606934, Validation accuracy: 0.6095123291015625

# %%
plot_graphs(history)

# %%
b_model = torch.load('./best_acc_model')

# %%
def predict(img, model):
    x = to_device(img.unsqueeze(0), device)
    y = model.forward(x)
    _, preds = torch.max(y, dim=1)

    return index2class[preds[0].item()]

# %%
with open(test_csv, 'r') as f:
    data = f.read()
    rows = data.split('\n')[1:-1]

# %%
ts_out = []
for i in rows:
    im = Image.open(os.path.join(test_path, i))
    im = transform(im)
    lab = predict(im, model)
    ts_out.append([i, lab])

test_outputs = pd.DataFrame(ts_out, columns=['ImageId', 'ClassName'])
test_outputs.to_csv('submit.csv')
